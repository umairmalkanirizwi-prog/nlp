# %% [markdown]
# <a href="https://colab.research.google.com/github/umairmalkanirizwi-prog/nlp/blob/main/NLP_EXP7_Umair.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Umair Malkani 242A004
import nltk
# Download the necessary resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
#Umair Malkani 242A004
text="""U.S. recognized India as an independent country on August 15, 1947, after British rule ended."""
print(text)
# Out:
# U.S. recognized India as an independent country on August 15, 1947, after British rule ended.

# %%
#Umair Malkani 242A004
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
#Umair Malkani 242A004
import nltk
nltk.download('punkt_tab')
tokens=word_tokenize(text)
print(tokens)
# Out:
# ['U.S.', 'recognized', 'India', 'as', 'an', 'independent', 'country', 'on', 'August', '15', ',', '1947', ',', 'after', 'British', 'rule', 'ended', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
#Umair Malkani 242A004
tagged_tokens=pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('U.S.', 'NNP'), ('recognized', 'VBD'), ('India', 'NNP'), ('as', 'IN'), ('an', 'DT'), ('independent', 'JJ'), ('country', 'NN'), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('after', 'IN'), ('British', 'JJ'), ('rule', 'NN'), ('ended', 'VBD'), ('.', '.')]

# %%
#Umair Malkani 242A004
import nltk
nltk.download('averaged_perceptron_tagger_eng')
tagged_tokens=pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('U.S.', 'NNP'), ('recognized', 'VBD'), ('India', 'NNP'), ('as', 'IN'), ('an', 'DT'), ('independent', 'JJ'), ('country', 'NN'), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('after', 'IN'), ('British', 'JJ'), ('rule', 'NN'), ('ended', 'VBD'), ('.', '.')]
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
#Umair Malkani 242A004
nltk.download('tagsets_json')
nltk.help.upenn_tagset("DT")
nltk.help.upenn_tagset("VBZ")
nltk.help.upenn_tagset("VBP")
nltk.help.upenn_tagset("VBG")
# Out:
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# ...

# %%
#Umair Malkani 242A004
import nltk
nltk.download('maxent_ne_chunker_tab')
named_entities = ne_chunk(tagged_tokens)
print(named_entities)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# (S
#   (GPE U.S./NNP)
#   recognized/VBD
#   (GPE India/NNP)
#   as/IN
#   an/DT
#   independent/JJ
#   country/NN
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   after/IN
#   (GPE British/JJ)
#   rule/NN
#   ended/VBD
#   ./.)

# %%
#Umair Malkani 242A004
from nltk.tree import Tree

# Display named entities
for subtree in named_entities:
    if isinstance(subtree, nltk.Tree):
        entity = " ".join([word for word, tag in subtree.leaves()])
        label = subtree.label()
        print(f"Entity: {entity}, Label: {label}")
# Out:
# Entity: U.S., Label: GPE
# Entity: India, Label: GPE
# Entity: British, Label: GPE

# %%
#Umair Malkani 242A004
# !pip install svgling
import svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.9 MB/s eta 0:00:00
# ...

# %%
#Umair Malkani 242A004
named_entities = ne_chunk(tagged_tokens)
named_entities
# Out:
# Tree('S', [Tree('GPE', [('U.S.', 'NNP')]), ('recognized', 'VBD'), Tree('GPE', [('India', 'NNP')]), ('as', 'IN'), ('an', 'DT'), ('independent', 'JJ'), ('country', 'NN'), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('after', 'IN'), Tree('GPE', [('British', 'JJ')]), ('rule', 'NN'), ('ended', 'VBD'), ('.', '.')])

# %%
#Umair Malkani 242A004
import spacy
#Load the spacy English model
nlp = spacy.load("en_core_web_sm")

#Sample text
text = "Apple is looking at buying U.K. startup for $1 billion. Bill Gates founded Microsoft."
#Process the text
doc = nlp(text)
#Extract named entities
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: Apple, Label: ORG
# Entity: U.K., Label: GPE
# Entity: $1 billion, Label: MONEY
# Entity: Bill Gates, Label: PERSON
# Entity: Microsoft, Label: ORG

# %%
#Part 1

# %%
#Umair Malkani 242A004
import nltk
from nltk import pos_tag, word_tokenize
from nltk.chunk import RegexpParser

# Sample sentence
sentence = "The quick brown fox jumps over the lazy dog."
sentence1 = "This is the class of natural language processing."

# Tokenization and POS tagging
tokens = word_tokenize(sentence1)
tagged = pos_tag(tokens)
tagged
# Out:
# [('This', 'DT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('class', 'NN'),
#  ('of', 'IN'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('.', '.')]

# %%
#Umair Malkani 242A004
grammar_1 = "NP: {<DT>?<JJ>*<NN>}"

# %%
#Umair Malkani 242A004
from nltk.chunk import RegexpParser
chunk_parser = RegexpParser(grammar_1)
chunks = chunk_parser.parse(tagged_tokens)
print(chunks)
# Out:
# (S
#   U.S./NNP
#   recognized/VBD
#   India/NNP
#   as/IN
#   (NP an/DT independent/JJ country/NN)
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   after/IN
#   (NP British/JJ rule/NN)
#   ended/VBD
#   ./.)

# %%
#Umair Malkani 242A004
from nltk.tree import tree
import svgling
svgling.draw_tree(chunks)
# Out:
# TreeLayout(Tree('S', [('U.S.', 'NNP'), ('recognized', 'VBD'), ('India', 'NNP'), ('as', 'IN'), Tree('NP', [('an', 'DT'), ('independent', 'JJ'), ('country', 'NN')]), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('after', 'IN'), Tree('NP', [('British', 'JJ'), ('rule', 'NN')]), ('ended', 'VBD'), ('.', '.')]))

# %%
#Umair Malkani 242A004
grammer_2 = "NP: {<DT>?<JJ>*<NN>}"
chunk_parser = RegexpParser(grammer_2)
chunks = chunk_parser.parse(tagged_tokens)
print(chunks)
# Out:
# (S
#   U.S./NNP
#   recognized/VBD
#   India/NNP
#   as/IN
#   (NP an/DT independent/JJ country/NN)
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   after/IN
#   (NP British/JJ rule/NN)
#   ended/VBD
#   ./.)

# %%
#Umair Malkani 242A004
print(chunks)
import svgling
svgling.draw_tree(chunks)
# Out:
# (S
#   U.S./NNP
#   recognized/VBD
#   India/NNP
#   as/IN
#   (NP an/DT independent/JJ country/NN)
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   after/IN
#   (NP British/JJ rule/NN)
#   ended/VBD
#   ./.)
# TreeLayout(Tree('S', [('U.S.', 'NNP'), ('recognized', 'VBD'), ('India', 'NNP'), ('as', 'IN'), Tree('NP', [('an', 'DT'), ('independent', 'JJ'), ('country', 'NN')]), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('after', 'IN'), Tree('NP', [('British', 'JJ'), ('rule', 'NN')]), ('ended', 'VBD'), ('.', '.')]))
